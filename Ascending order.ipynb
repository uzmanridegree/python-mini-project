# %%
numbers=[0,6,1,8,10,3]
asc_order=[]
def mini(num):
   min_val=num[0]
   for x in num:
    if x<=min_val:
       min_val=x
   num.remove(min_val)
   asc_order.append(min_val)
for x in range(len(numbers)):
     mini(numbers)
print(asc_order)
# Out:
# [0, 1, 3, 6, 8, 10]
